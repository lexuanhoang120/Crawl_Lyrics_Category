# %%
import pandas as pd

# %%
df = pd.read_csv("D:\DS Projects\My_Crawl_Data\data_nhaccuatui_0-5k.csv")
df = df.iloc[:,2:]
df.iloc[:40]
# Out:
#                                title                           singer  id  \
# 0               Anh Hứa Rồi Lại Quên                      Lâm Bảo Nam NaN
# 1                    Anh Khác Họ Hai                            A.L.T NaN
# 2          Anh Khác Người Ấy (Remix)                       Khắc Trung NaN
# 3     Anh Không Bao Giơ (Toi Jamais)                        Thanh Lan NaN
# 4           And If You Need Somebody            Bảo Thy & Vương Khang NaN
# 5     Anh Không Còn Tin Vào Tình Yêu                           An Nam NaN
# 6                      Anh Không Cần        Duy Cường & Luka Huy Phạm NaN
# 7                      Anh Không Cần       Phạm Thiên Huy & Duy Cường NaN
# 8                 Anh Không Cần Biết                       Khánh Đăng NaN
# 9     Anh Không Cần Tình Em Gian Dối                          Trí Hải NaN
# 10                     Anh Không Giữ                      Tiên Cookie NaN
# 11         Anh Không Hiểu (Remix DJ)                         Quang Hà NaN
# ...
