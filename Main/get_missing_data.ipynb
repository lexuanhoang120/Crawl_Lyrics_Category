# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "D:/DS Projects/My_Crawl_Data/Data/"
df0 = pd.read_csv(path + "data_19k-end.csv")
df0 = df0.iloc[:2001,1:]
df0_na = df0.isnull()
df0_na = df0[(df0_na.Genre == True) | (df0_na.Lyric == True)] [["title","singer" ]]
df0_na
# Out:
#                                   title                      singer
# 0                  Anh Hứa Rồi Lại Quên                 Lâm Bảo Nam
# 1                       Anh Khác Họ Hai                       A.L.T
# 2             Anh Khác Người Ấy (Remix)                  Khắc Trung
# 3        Anh Không Bao Giơ (Toi Jamais)                   Thanh Lan
# 4              And If You Need Somebody       Bảo Thy & Vương Khang
# ...                                 ...                         ...
# 1996  Em Thay Đổi Hay Anh Không Còn Yêu              Vĩnh Thiên Kim
# 1997                       Em Thích Anh                       H.A.T
# 1998                             Em Tôi  Hồng Ngọc & Hồ Quỳnh Hương
# 1999            Em Tường Mình Vai Chính              Lương Khánh Vy
# 2000                          Em Và Tôi                   Bằng Kiều
#
# [2001 rows x 2 columns]

# %%
df2 = pd.read_csv(path + "check_data_2k-4k.csv")
df2 = df2.iloc[2001:4001,1:]
df2_na = df2.isnull()
df2_na = df2[(df2_na.Genre == True) | (df2_na.Lyric == True)] [["title","singer" ]]
df2_na
# Out:
#                        title                       singer
# 2002          Em Vẫn Chờ Anh                     Cát Tiên
# 2003          Em Vẫn Chờ Anh                    Loan Châu
# 2006  Em Vẫn Mãi Là Niềm Đau                 Elvis Phương
# 2008   Em Vẫn Mơ Một Ngày Về         Cát Lynh & Hồng Diễm
# 2010          Em Vẫn Đợi Anh                   Minh Tuyết
# ...                      ...                          ...
# 3995                  Mẹ Tôi                    Giao Linh
# 3996         Mẹ Tôi Rước Dâu       Bích Thảo & Nguyễn Tâm
# 3998      Mẹ Từ Bi& Chúa Tôi  Hương Thủy & Kỳ Phương Uyên
# 3999          Mẹ Yêu (Remix)              Châu Khải Phong
# 4000                  Mẹ Yêu                    Tuấn Hưng
#
# [1058 rows x 2 columns]

# %%
df4 = pd.read_csv(path + "data_4k-6k.csv")
df4 = df4.iloc[4001:6001,1:]
df4_na = df4.isnull()
df4_na = df4[(df4_na.Genre == True) | (df4_na.Lyric == True)] [["title","singer" ]]
df4_na
# Out:
#                            title            singer
# 4004         Mẹ Ơi Xin Đừng Khóc     Thái Lan Viên
# 4008  Mấy Ai Tránh Được Chữ Tình  Trương Vĩnh Toàn
# 4009           Mắt Tím Hoàng Hôn    Đoàn Ngọc Thảo
# 4010          Mẹ Hiền Yêu Thương         Phước Hải
# 4011                     Mỏi Mòn       Triệu Hoàng
# ...                          ...               ...
# 5995    Thương Về Vùng Hỏa Tuyến         Hồng Trúc
# 5996            Thương Về Xứ Huế          Cao Minh
# 5998             Thương Áo Bà Ba         Phi Nhung
# 5999              Thương Đời Hoa            Khả Tú
# 6000              Thương Đời Hoa       Thiên Trang
#
# [1316 rows x 2 columns]

# %%
df6 = pd.read_csv(path + "data_6k-8k.csv")
df6 = df6.iloc[6001:8001,1:]
df6_na = df4.isnull()
df6_na = df4[(df6_na.Genre == True) | (df6_na.Lyric == True)] [["title","singer" ]]
df6_na
# Out:
#                            title            singer
# 4004         Mẹ Ơi Xin Đừng Khóc     Thái Lan Viên
# 4008  Mấy Ai Tránh Được Chữ Tình  Trương Vĩnh Toàn
# 4009           Mắt Tím Hoàng Hôn    Đoàn Ngọc Thảo
# 4010          Mẹ Hiền Yêu Thương         Phước Hải
# 4011                     Mỏi Mòn       Triệu Hoàng
# ...                          ...               ...
# 5995    Thương Về Vùng Hỏa Tuyến         Hồng Trúc
# 5996            Thương Về Xứ Huế          Cao Minh
# 5998             Thương Áo Bà Ba         Phi Nhung
# 5999              Thương Đời Hoa            Khả Tú
# 6000              Thương Đời Hoa       Thiên Trang
#
# [1316 rows x 2 columns]

# %%
df8 = pd.read_csv(path + "data_8k-10k.csv")
df8 = df8.iloc[8001:10001,1:]
df8_na = df8.isnull()
df8_na = df8[(df8_na.Genre == True) | (df8_na.Lyric == True)] [["title","singer" ]]
df8_na
# Out:
#                              title                  singer
# 8002               Ánh Mắt Vô Hình             Tống Gia Vỹ
# 8003              Ánh Mắt Đưa Tình     Minh Trí & Việt Thy
# 8004                  Ánh Sao Băng                 Sỹ Luân
# 8006   Ánh Sáng Nơi Cuối Con Đường  Eddy Viet & Lil Knight
# 8007             Ánh Trăng Biệt Ly               Đăng Khôi
# ...                            ...                     ...
# 9982        Xa Mot Troi Thuong Nho         Châu Khải Phong
# 9988       Yeu Khong Oan Khong Hoi                 Anh Duy
# 9993            yeu nguoi thay doi                 Gia Huy
# 9994                Yeu Nham Nguoi             Lê Bảo Bình
# 10000  Yeu Thuong Ngay Do (Guitar)         Sobin Hoàng Sơn
#
# [1042 rows x 2 columns]

# %%
df10 = pd.read_csv(path + "data_10k-12k.csv")
df10 = df10.iloc[10001:12001,1:]
df10_na = df10.isnull()
df10_na = df10[(df10_na.Genre == True) | (df10_na.Lyric == True)] [["title","singer" ]]
df10_na
# Out:
#                                       title                   singer
# 10001  Yeu Thuong Nhau Tai Sao De Nhau Buon                 Soái Nhi
# 10004                            Vi Anh Sai             Thành Nghiệp
# 10008              Vi Con Xin Em Dung Ra Di           Lâm Chấn Khang
# 10011                    Vi Long Con Thuong  Quỳnh Trang, Lưu Chí Vỹ
# 10013                 Vi mua co vui bao gio             Phạm Anh Duy
# ...                                     ...                      ...
# 11994                              Nhip Dap              Đoàn Bá Chi
# 11996                  NHỚ MÃI MỘT MIỀN QUÊ    Huyền Trang, Phi Hùng
# 11997                  NHỚ MẸ HIỀN (TÂN CỔ)              TRỌNG PHƯỚC
# 11998                         NHỚ MỘT NGƯỜI                Đăng Vinh
# 11999                         NHỚ NGƯỜI YÊU               Bằng Cường
#
# [892 rows x 2 columns]

# %%
df12 = pd.read_csv(path + "data_12k-13k.csv")
df12 = df12.iloc[12001:13001,1:]
df12_na = df12.isnull()
df12_na = df12[(df12_na.Genre == True) | (df12_na.Lyric == True)] [["title","singer" ]]
df12_na
# Out:
#                           title                           singer
# 12001           NHỚ QUÁ SÀI GÒN                        Diệu Hiền
# 12003   NHỮNG NGÀY SAU CHIA TAY                  Nguyễn Thành An
# 12004    NHỮNG NGÀY VUI TRỞ LẠI  Châu Khải Phong & Liễu Ngọc Lan
# 12006          NGÀY XƯA ANH NÓI        Lưu Ánh Loan & Lưu Chí Vỹ
# 12007    NGƯỜI LÁI ĐÒ SANG SÔNG                  Lưu Huyền Trinh
# ...                         ...                              ...
# 12991   TÂM SỰ ĐỜI TÔI (TÂN CỔ)                           Lệ Thu
# 12993                 TÂY DU KÝ                    Rick Anh Tuấn
# 12994  TÌM CHA NƠI ĐÂU (TÂN CỔ)                          Vũ Luân
# 12995       TÌM KIẾM EM NƠI ĐÂU                    Kiun Gia Tuấn
# 12997           TÌM VỀ NIỀM TIN                       Thanh Ngọc
#
# [354 rows x 2 columns]

# %%
df13 = pd.read_csv(path + "data_13k-15k.csv")
df13 = df13.iloc[13001:15001,1:]
df13_na = df13.isnull()
df13_na = df13[(df13_na.Genre == True) | (df13_na.Lyric == True)] [["title","singer" ]]
df13_na
# Out:
#                                      title                            singer
# 13002                 TÌNH CA NGƯỜI THỢ MỎ                         Quang Thọ
# 13003                     TÌNH CA TRÊN LÚA            Mạnh Quỳnh & Thúy Hằng
# 13004              TÌNH DUYÊN MÙA NƯỚC NỔI                     Đặng Thế Luân
# 13006            TÌNH DƠN PHƯƠNG 2 (REMIX)  Sinti Quang Tùng & Thái Lan Viên
# 13007                 TÌNH KHÔNG ĐOẠN CUỐI          HÀ THANH XUÂN,MẠNH QUỲNH
# ...                                    ...                               ...
# 14988                    Nhung Doi Hoa Sim                         Sơn Tuyền
# 14990                Nhung Dong Thu Hoi Am                       Lê Việt Anh
# 14991                    Nhung Em Be Ngoan                    Nhạc Thiếu Nhi
# 14994  Nhung Gian Doi Chi Lam Long Don Dau                        Lưu Chí Vỹ
# 14998                  Nhung Kiep Hoa Xuan                          Ngọc Lan
#
# [932 rows x 2 columns]

# %%
df15 = pd.read_csv(path + "data_15k-17k.csv")
df15 = df15.iloc[15001:17001,1:]
df15_na = df15.isnull()
df15_na = df15[(df15_na.Genre == True) | (df15_na.Lyric == True)] [["title","singer" ]]
df15_na
# Out:
#                                  title                           singer
# 15001               Nhung Loi Doi Gian                       Lam Trường
# 15002               Nhung Loi Doi Gian                         Lây Minh
# 15003               Nhung Loi Doi Gian                       Minh Tuyết
# 15004                Nhung Loi Me Hoac        Trần Thái Hòa, Minh Tuyết
# 15008               Nhung Nam Mo Hoang      Lâm Nhật Tiến, Lâm Thúy Vân
# ...                                ...                              ...
# 16992  Da Den Luc Anh Phai Noi (Remix)                     Bùi Anh Tuấn
# 16993                  Da Het That Roi                            Yanbi
# 16994            Da Khong Yeu Thi Thoi                        Nguyên Vũ
# 16995                          Da Khuc                           Huy Vũ
# 17000           Da Khuc Nua Vang Trang  Dan Nguyen ft Nguyen Hong Nhung
#
# [752 rows x 2 columns]

# %%
df17 = pd.read_csv(path + "data_17k-19k.csv")
df17 = df17.iloc[17001:19001,1:]
df17_na = df17.isnull()
df17_na = df17[(df17_na.Genre == True) | (df17_na.Lyric == True)] [["title","singer" ]]
df17_na
# Out:
#                                          title  \
# 17001                    Dã Chẳng Còn Niềm Tin
# 17002                               HongKong 1
# 17003                                Không Dám
# 17005                                  Not Shy
# 17006                             Sầu Hồng Gai
# ...                                        ...
# 18996                   HÔN SÂU 3 PHÚT (PIANO)
# 18997  Khúc Tâm Tình Của Người Hà Tĩnh Tone Nữ
# 18998                   Mệt Rồi Đi Rồi Tan Rồi
# 18999           Một Câu Chuyện Buồn (TONE NAM)
# 19000       Ngày Mưa Em Có Buồn Không(TONE NỮ)
#
#                                                   singer
# 17001                                  Phạm Thành Nguyên
# 17002                                   Nguyễn Trọng Tài
# 17003                                           Lynk Lee
# 17005                                           ITZY(있지)
# 17006                                      Jombie & Tkan
# ...

# %%
df19 = pd.read_csv(path + "data_19k-end.csv")
df19 = df19.iloc[19001:,1:]
df19_na = df19.isnull()
df19_na = df19[(df19_na.Genre == True) | (df19_na.Lyric == True)] [["title","singer" ]]
df19_na
# Out:
#                                                    title  \
# 19003                                     Nếu (Lofi Ver)
# 19007                                                SAY
# 19008                                 Sài Gòn Yêu Thương
# 19011                                            Sủng Ái
# 19013                                   Thiên Sứ Cá Nhân
# ...                                                  ...
# 20538              XIN CHO MÃI YÊU (LOFI MUSIC) TONE NAM
# 20539  Xin Chào Ngày Mai Tone Nữ ( ming tian ni hao 明...
# 20540                                You Are My Sunshine
# 20541                                          What's Up
# 20542                                        Được Và Mất
#
#                                singer
# 19003                           Reddy
# 19007          ĐAN NGUYÊN, QUỐC KHANH
# 19008                   Đàm Vĩnh Hưng
# 19011            TFBoys (chǒng ài 宠爱)
# 19013  TANK (zhuān shǔ tiān shǐ 专属天使)
# ...                               ...
# ...

# %%
df = pd.concat([df0_na,df2_na,df4_na,df6_na,df8_na,df10_na,df12_na,df13_na,df15_na,df17_na,df19], axis = 0, ignore_index=True)
df.drop_duplicates()
df.to_csv("D:/DS Projects/My_Crawl_Data/Output/Missing_Song_Data.csv")
df.info
# Out:
# <bound method DataFrame.info of                                                    title  \
# 0                                   Anh Hứa Rồi Lại Quên
# 1                                        Anh Khác Họ Hai
# 2                              Anh Khác Người Ấy (Remix)
# 3                         Anh Không Bao Giơ (Toi Jamais)
# 4                               And If You Need Somebody
# ...                                                  ...
# 12306              XIN CHO MÃI YÊU (LOFI MUSIC) TONE NAM
# 12307  Xin Chào Ngày Mai Tone Nữ ( ming tian ni hao 明...
# 12308                                You Are My Sunshine
# 12309                                          What's Up
# 12310                                        Được Và Mất
#
#                               singer        id       Genre Lyric
# 0                        Lâm Bảo Nam       NaN         NaN   NaN
# 1                              A.L.T       NaN         NaN   NaN
# ...

# %%
df.iloc[100:112]
# Out:
#                               title                   singer  id Genre Lyric
# 100                     Anh Vẫn Chờ           Hồng Dương M4U NaN   NaN   NaN
# 101                     Anh Vẫn Chờ             La Phong Lâm NaN   NaN   NaN
# 102                   Anh Về Với Em  Ngọc Minh & Thanh Phong NaN   NaN   NaN
# 103                  Anh Xin Lỗi Em              Dương Khang NaN   NaN   NaN
# 104  Anh Yêu Người Khác Rồi (Remix)                Khắc Việt NaN   NaN   NaN
# 105                     Anh Đã Biết             Danny Nguyen NaN   NaN   NaN
# 106                       Boulevard                 Duy Hạnh NaN   NaN   NaN
# 107           Bâng Khuâng Trường Sa              Nhiều Ca Sỹ NaN   NaN   NaN
# 108               Canh Chim Lạc Lối           Lưu Minh Thắng NaN   NaN   NaN
# 109          Anh Vẫn Không Đổi Thay               Kenny Thái NaN   NaN   NaN
# 110          Anh Vẫn Không Đổi Thay                  Lê Toàn NaN   NaN   NaN
# ...
